# %% [markdown]
# <a href="https://colab.research.google.com/github/Jalaludin17/My-Machine-Learning-Projects/blob/main/01%20Heart%20Disease%20prediction%20using%20ML/Heart_Disease_Prediction_using_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**<font color="Orange">Heart Disease Prediction using Machine Learning**

# %% [markdown]
# ![cardiac-disease-banner 2.png](data:image/png;base64,...)

# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd

#Impoting data sets directly from source web link to google Colab notebook
# URL of the dataset
url = 'https://media.geeksforgeeks.org/wp-content/uploads/20240307152534/framingham.csv'

# Read CSV directly into a pandas DataFrame
df = pd.read_csv(url)

# Display the first few rows
print(df.head())
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
#Lets review all columns and data
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# !pip install pandas_profiling

# %%
#Summary of the data
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %%
#Checking null values
df.isnull().sum()

#Five columns have null values
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
#Shape of Data
df.shape
# Out:
# (4240, 16)

# %%
#Removing NaN / NULL values
df.dropna(axis = 0, inplace = True)

# %%
df.shape
# Out:
# (3658, 16)

# %%
#Check data set again
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
#Lets have a look at ratio of positive and negative value for disease
print(df.TenYearCHD.value_counts())
# Out:
# TenYearCHD
# 0    3101
# 1     557
# Name: count, dtype: int64

# %%
#Droping unnecessary columns and rename
df.drop(['education'], inplace = True, axis = 1)
df.rename(columns ={'male':'Gender'}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3658 entries, 0 to 4239
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           3658 non-null   int64
#  1   age              3658 non-null   int64
#  2   currentSmoker    3658 non-null   int64
#  3   cigsPerDay       3658 non-null   float64
#  4   BPMeds           3658 non-null   float64
#  5   prevalentStroke  3658 non-null   int64
#  6   prevalentHyp     3658 non-null   int64
#  7   diabetes         3658 non-null   int64
#  8   totChol          3658 non-null   float64
#  9   sysBP            3658 non-null   float64
#  10  diaBP            3658 non-null   float64
#  11  BMI              3658 non-null   float64
#  12  heartRate        3658 non-null   float64
#  13  glucose          3658 non-null   float64
#  14  TenYearCHD       3658 non-null   int64
# dtypes: float64(8), int64(7)
# memory usage: 457.2 KB

# %%
#Now lets check co-relation between each column uisng heatmap or Correlation matrix
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
#Feature enginnering
#Dealing with numerical and categorical columns
# Separate numerical and categorical features
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
cat_cols = df.select_dtypes(include=['object', 'category']).columns

num_cols, cat_cols
#The data donot have any categorical column
#Gender column is also coded as 1 for male and 0 for female
# Out:
# (Index(['Gender', 'age', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#         'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#         'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#        dtype='object'),
#  Index([], dtype='object'))

# %%
# Correlation with the target (TenYearCHD)
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
correlation_matrix = df.corr()  # Assign the result of df.corr() to correlation_matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# <ul>
#   <li><font color="white">The column <strong>TenYearCHD</strong> seems to be the target variable, representing whether an individual is likely to develop coronary heart disease (CHD) within the next ten years.</font></li>
#   <li><font color="white">Columns which have a strong correlation with <strong>TenYearCHD</strong>:</font></li>
#   <ul>
#     <li><font color="white"><strong>Age (0.233983):</strong> Older age has a stronger positive relationship with CHD risk.</font></li>
#     <li><font color="white"><strong>sysBP (0.222821):</strong> Higher systolic blood pressure correlates with higher CHD risk.</font></li>
#     <li><font color="white"><strong>prevalentHyp (0.181387):</strong> Presence of hypertension is moderately correlated with CHD risk.</font></li>
#   </ul>
# </ul>

# %%
# Visualizing relationships
# Example: Distribution of a numerical feature by the target
sns.boxplot(x='TenYearCHD', y='age', data=df)
plt.title("Age vs TenYearCHD")
plt.show()

# %%
sns.boxplot(x='TenYearCHD', y='sysBP', data=df)
plt.title("Systolic Blood Pressure vs TenYearCHD")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x='TenYearCHD', y='prevalentHyp', data=df)
plt.title("Prevalent Hypertension vs TenYearCHD")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x='TenYearCHD', y='diaBP', data=df)
plt.title("Diastolic Blood Pressure vs TenYearCHD")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Create a copy of df
data_set=df.copy()

# %%
#Droping unnesecassary columns with with weak co relation with target column
data_set=data_set.drop(columns=['diaBP','glucose','totChol','BPMeds','BMI','cigsPerDay','prevalentStroke','heartRate','currentSmoker'],axis=1)
data_set.head()
# Out:
#    Gender  age  prevalentHyp  diabetes  sysBP  TenYearCHD
# 0       1   39             0         0  106.0           0
# 1       0   46             0         0  121.0           0
# 2       1   48             0         0  127.5           0
# 3       0   61             1         0  150.0           1
# 4       0   46             0         0  130.0           0

# %%
#Rounding off the numbers
data_set['sysBP']=data_set['sysBP'].round(0)
data_set
# Out:
#       Gender  age  prevalentHyp  diabetes  sysBP  TenYearCHD
# 0          1   39             0         0  106.0           0
# 1          0   46             0         0  121.0           0
# 2          1   48             0         0  128.0           0
# 3          0   61             1         0  150.0           1
# 4          0   46             0         0  130.0           0
# ...      ...  ...           ...       ...    ...         ...
# 4233       1   50             1         0  179.0           1
# 4234       1   51             0         0  126.0           0
# 4237       0   52             0         0  134.0           0
# 4238       1   40             1         0  141.0           0
# 4239       0   39             0         0  133.0           0
#
# [3658 rows x 6 columns]

# %% [markdown]
# ## Machine Learning

# %%
# Basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Machine Learning Models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier

# Metrics and Utilities
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, accuracy_score
from sklearn.preprocessing import StandardScaler

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Split the dataset into features (X) and target (y)
X = df.drop(columns=['TenYearCHD'])
y = df['TenYearCHD']

# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# ##Step 4 : Train the models

# %% [markdown]
# ###Logistic Regression Model

# %%
log_model = LogisticRegression()
log_model.fit(X_train, y_train)
log_preds = log_model.predict(X_test)
log_probs = log_model.predict_proba(X_test)[:, 1]

# %%
# Assuming 'df' is your DataFrame
features = df.drop(columns=['TenYearCHD']).columns

# Get the coefficients of the logistic regression model
coefficients = log_model.coef_[0]

print("Intercept:", log_model.intercept_)
print("Coefficients:", dict(zip(features, coefficients)))
# Out:
# Intercept: [-1.99797732]
# Coefficients: {'Gender': 0.2457287453268532, 'age': 0.5468098249883482, 'currentSmoker': -2.4965464964150233e-05, 'cigsPerDay': 0.22889128253699698, 'BPMeds': 0.03971345407900289, 'prevalentStroke': 0.03217118203830472, 'prevalentHyp': 0.13542363438061242, 'diabetes': -0.02913091564069548, 'totChol': 0.11844365775302539, 'sysBP': 0.3570053416978568, 'diaBP': -0.05433377409554212, 'BMI': 0.03369220182594437, 'heartRate': -0.050689965573544826, 'glucose': 0.2245418197850597}

# %% [markdown]
# ###Random Forest Model

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
rf_preds = rf_model.predict(X_test)
rf_probs = rf_model.predict_proba(X_test)[:, 1]

# %%
# Extract feature importance
rf_importances = rf_model.feature_importances_

print("Number of Trees:", len(rf_model.estimators_))
print("Feature Importances:", dict(zip(features, rf_importances)))
# Out:
# Number of Trees: 100
# Feature Importances: {'Gender': 0.021661201514251948, 'age': 0.1330701113149521, 'currentSmoker': 0.012344469086175636, 'cigsPerDay': 0.0500523066041715, 'BPMeds': 0.00755572161207882, 'prevalentStroke': 0.002483233737271166, 'prevalentHyp': 0.017923180231904434, 'diabetes': 0.0059479344251285645, 'totChol': 0.12391331214495428, 'sysBP': 0.14233424586928672, 'diaBP': 0.12342588391800823, 'BMI': 0.13306687837007428, 'heartRate': 0.09936509855133535, 'glucose': 0.12685642262040703}

# %% [markdown]
# ###Gradient Boosting XGBoost Model

# %%
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb_model.fit(X_train, y_train)
xgb_preds = xgb_model.predict(X_test)
xgb_probs = xgb_model.predict_proba(X_test)[:, 1]

# %%
print("Feature Importances (XGBoost):", dict(zip(features, xgb_model.feature_importances_)))
print("Parameters:", xgb_model.get_params())
# Out:
# Feature Importances (XGBoost): {'Gender': 0.103220046, 'age': 0.10452816, 'currentSmoker': 0.07174826, 'cigsPerDay': 0.073267564, 'BPMeds': 0.1091385, 'prevalentStroke': 0.0, 'prevalentHyp': 0.08012547, 'diabetes': 0.057692535, 'totChol': 0.064898185, 'sysBP': 0.082859494, 'diaBP': 0.06279308, 'BMI': 0.062559724, 'heartRate': 0.061879333, 'glucose': 0.065289706}
# ...

# %% [markdown]
# ###Neural Network Model

# %%
nn_model = MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=200, random_state=42)
nn_model.fit(X_train, y_train)
nn_preds = nn_model.predict(X_test)
nn_probs = nn_model.predict_proba(X_test)[:, 1]

# %%
print("Weights:", nn_model.coefs_)
print("Biases:", nn_model.intercepts_)
# Out:
# Weights: [array([[ 9.34944249e-03,  4.18917943e-01,  1.65123426e-01,
#          1.26085234e-01, -2.99136056e-01, -4.06305478e-01,
#         -5.21657969e-01,  3.19690070e-01, -7.86856623e-03,
#          1.43770090e-01, -3.04401468e-01,  4.61806179e-01,
#          4.61017212e-01, -1.66305498e-01, -2.90853494e-01,
#         -2.44372553e-01,  1.21194764e-01,  3.13651095e-02,
#         -2.49488466e-01, -2.51854926e-01,  1.51426998e-01,
#         -3.34906739e-01, -2.58465370e-01, -3.80687358e-01,
#          2.44243990e-01,  1.09430250e-01, -2.63314392e-01,
#         -6.38223287e-02,  3.61107710e-02, -4.01584356e-01,
#         -5.79156279e-02, -5.98383278e-01, -3.11888808e-01,
#          2.65751529e-02,  2.56757510e-01,  2.06029387e-01,
#         -1.72948066e-01, -1.66095686e-01, -9.06118256e-02,
#         -6.03766722e-03, -3.75879597e-01, -2.05546245e-01,
#         -3.15551055e-01,  3.76564684e-01, -1.88063135e-01,
#          2.64174291e-01, -2.86695174e-01, -3.84331293e-02,
# ...

# %% [markdown]
# ##Evaluating Performace

# %% [markdown]
# ###1.Metrics

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

def evaluate_model(y_test, preds, probs):
    print("Classification Report:")
    print(classification_report(y_test, preds))

    accuracy = accuracy_score(y_test, preds)
    precision = precision_score(y_test, preds)
    recall = recall_score(y_test, preds)
    f1 = f1_score(y_test, preds)
    roc_auc = roc_auc_score(y_test, probs)

    print(f"Accuracy: {accuracy:.2f}")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1-Score: {f1:.2f}")
    print(f"ROC-AUC: {roc_auc:.2f}")

    return accuracy, precision, recall, f1, roc_auc

print("Logistic Regression:")
log_metrics = evaluate_model(y_test, log_preds, log_probs)

print("\nRandom Forest:")
rf_metrics = evaluate_model(y_test, rf_preds, rf_probs)

print("\nXGBoost:")
xgb_metrics = evaluate_model(y_test, xgb_preds, xgb_probs)

print("\nNeural Network:")
nn_metrics = evaluate_model(y_test, nn_preds, nn_probs)
# Out:
# Logistic Regression:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.92       621
#            1       0.73      0.14      0.24       111
#
#     accuracy                           0.86       732
#    macro avg       0.80      0.57      0.58       732
# weighted avg       0.85      0.86      0.82       732
#
# Accuracy: 0.86
# Precision: 0.73
# Recall: 0.14
# F1-Score: 0.24
# ROC-AUC: 0.73
#
# Random Forest:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       621
#            1       0.56      0.08      0.14       111
#
#     accuracy                           0.85       732
#    macro avg       0.71      0.53      0.53       732
# weighted avg       0.81      0.85      0.80       732
#
# Accuracy: 0.85
# Precision: 0.56
# Recall: 0.08
# F1-Score: 0.14
# ROC-AUC: 0.71
#
# XGBoost:
# Classification Report:
# ...

# %% [markdown]
# ###2. Confusuin Metrics

# %%
def plot_confusion_matrix(y_test, preds, title):
    cm = confusion_matrix(y_test, preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

plot_confusion_matrix(y_test, log_preds, "Logistic Regression Confusion Matrix")
plot_confusion_matrix(y_test, rf_preds, "Random Forest Confusion Matrix")
plot_confusion_matrix(y_test, xgb_preds, "XGBoost Confusion Matrix")
plot_confusion_matrix(y_test, nn_preds, "Neural Network Confusion Matrix")

# %% [markdown]
# ###3. ROC Curve

# %%
def plot_roc_curve(y_test, probs, label):
    fpr, tpr, _ = roc_curve(y_test, probs)
    plt.plot(fpr, tpr, label=f"{label} (AUC = {roc_auc_score(y_test, probs):.2f})")

plt.figure(figsize=(10, 7))
plot_roc_curve(y_test, log_probs, "Logistic Regression")
plot_roc_curve(y_test, rf_probs, "Random Forest")
plot_roc_curve(y_test, xgb_probs, "XGBoost")
plot_roc_curve(y_test, nn_probs, "Neural Network")
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# ##Compare Models

# %%
results = pd.DataFrame({
    "Model": ["Logistic Regression", "Random Forest", "XGBoost", "Neural Network"],
    "Accuracy": [log_metrics[0], rf_metrics[0], xgb_metrics[0], nn_metrics[0]],
    "Precision": [log_metrics[1], rf_metrics[1], xgb_metrics[1], nn_metrics[1]],
    "Recall": [log_metrics[2], rf_metrics[2], xgb_metrics[2], nn_metrics[2]],
    "F1-Score": [log_metrics[3], rf_metrics[3], xgb_metrics[3], nn_metrics[3]],
    "ROC-AUC": [log_metrics[4], rf_metrics[4], xgb_metrics[4], nn_metrics[4]],
})
print(results)
# Out:
#                  Model  Accuracy  Precision    Recall  F1-Score   ROC-AUC
# 0  Logistic Regression  0.862022   0.727273  0.144144  0.240602  0.725378
# 1        Random Forest  0.851093   0.562500  0.081081  0.141732  0.714171
# 2              XGBoost  0.818306   0.250000  0.099099  0.141935  0.648649
# 3       Neural Network  0.822404   0.297872  0.126126  0.177215  0.663591

# %% [markdown]
# ## Graphical user interface for non technical user (front end)

# %%
#convert the best model into pickle file
import pickle

with open('log_model.pkl', 'wb') as file:
    pickle.dump(log_model, file)

# %%
#install gradio liberary for ui development
# !pip install gradio

# %%
import gradio as gr
import pickle

# Load the trained model
with open('log_model.pkl', 'rb') as file:
    model_LR = pickle.load(file)

# Define the prediction function
def predict_chd(age, prevalentHyp, sysBP, diaBP, glucose):
    # Prepare the input data for prediction
    input_data = [[age, prevalentHyp, sysBP, diaBP, glucose]]

    # Get the prediction from the model
    prediction = model_LR.predict(input_data)

    # Return the result as a human-readable string
    return "Positive he should take care" if prediction[0] == 1 else "Negative (No CHD risk)"

# Create the Gradio interface
interface = gr.Interface(
    fn=predict_chd,
    inputs=[
        gr.Number(label="Age", value=50, precision=0),
        gr.Radio(label="Prevalent Hypertension (prevalentHyp)", choices=[1, 0], type="value"),
        gr.Number(label="Systolic Blood Pressure (sysBP)", value=120),
        gr.Number(label="Diastolic Blood Pressure (diaBP)", value=80),
        gr.Number(label="Glucose Level", value=90),
    ],
    outputs=gr.Textbox(label="Prediction Result"),
    title="Ten-Year CHD Risk Prediction",
    description="Enter the patient's details to predict the Ten-Year Coronary Heart Disease (CHD) risk using a Logistic Regression model.",
)

# Launch the interface
interface.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://7aff2c4b755a7c683b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://7aff2c4b755a7c683b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
